# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

participant_data = pd.read_csv("Demographics Information - Human Participants.csv")
print(participant_data.shape)
participant_data.head()
# Out:
# (175, 22)
#                                    Study Name/Number Race  Present Ethnicity  \
# 0  Abdominal and Direct Fetal ECG Database: Multi...    X        0         X
# 1  AF Termination Challenge Database: ECG recordi...    X        0         X
# 2  AHA Database Sample Excluded Record: Two ECG s...    X        0         X
# 3  A large scale 12-lead electrocardiogram databa...    X        0         X
# 4  A multi-camera and multimodal dataset for post...    X        0         X
#
#    Present.1                                  Study sample size Male Female  \
# 0          0                     5 women in labor were analyzed    X      X
# 1          0  Three groups in Learning Set: 1.  Group N (non...    X      X
# 2          0  80 recordings (10 for each existing condition)...    X      X
# 3          0                                   45, 152 patients    X      X
# 4          0                                                 14   10      4
#
# ...

# %%
plt.show(sns.displot(x='Present', data=participant_data))

plt.show(sns.displot(x='Present.1', data=participant_data))

# plt.show(sns.displot(x="Present", y="Present.2", data=participant_data, cbar=True))

# %%
participant_data.groupby("Present").count() # counts for race reporting
# Out:
#          Study Name/Number  Race  Ethnicity  Present.1  Study sample size  \
# Present
# 0                      165   165        165        165                165
# 1                       10    10         10         10                 10
#
#          Male  Female  Total N  Gender/Sex  Present.2  ...  Present.3  \
# Present                                                ...
# 0         165     165      165         165        165  ...        165
# 1          10      10       10          10         10  ...         10
#
#          Country/Region  Location   Pre-existing conditions and/or Symptoms  \
# Present
# 0                   165        153                                      139
# 1                    10         10                                        6
#
#          Instruments used  Socioeconomic Status  \
# Present
# 0                     135                   148
# 1                       7                     8
#
#          Data Collected (differnent levels of)  \
# ...

# %%
participant_data.groupby("Present.1").count() # ethnicity reporting
# Out:
#            Study Name/Number  Race  Present  Ethnicity  Study sample size  \
# Present.1
# 0                        169   169      169        169                169
# 1                          6     6        6          6                  6
#
#            Male  Female  Total N  Gender/Sex  Present.2  ...  Present.3  \
# Present.1                                                ...
# 0           169     169      169         169        169  ...        169
# 1             6       6        6           6          6  ...          6
#
#            Country/Region  Location   Pre-existing conditions and/or Symptoms  \
# Present.1
# 0                     169        157                                      140
# 1                       6          6                                        5
#
#            Instruments used  Socioeconomic Status  \
# Present.1
# 0                       137                   150
# 1                         5                     6
#
# ...

# %%
participant_data.groupby("Present.2").count() # gender reporting
# Out:
#            Study Name/Number  Race  Present  Ethnicity  Present.1  \
# Present.2
# 0                         54    54       54         54         54
# 1                        121   121      121        121        121
#
#            Study sample size  Male  Female  Total N  Gender/Sex  ...  \
# Present.2                                                        ...
# 0                         54    54      54       54          54  ...
# 1                        121   121     121      121         121  ...
#
#            Present.3  Country/Region  Location   \
# Present.2
# 0                 54              54         45
# 1                121             121        118
#
#            Pre-existing conditions and/or Symptoms  Instruments used  \
# Present.2
# 0                                               38                36
# 1                                              107               106
#
#            Socioeconomic Status  Data Collected (differnent levels of)  \
# Present.2
# ...

# %%
participant_data.groupby("Present.3").count() # age reporting
# Out:
#            Study Name/Number  Race  Present  Ethnicity  Present.1  \
# Present.3
# 0                         50    50       50         50         50
# 1                        125   125      125        125        125
#
#            Study sample size  Male  Female  Total N  Gender/Sex  ...  Age  \
# Present.3                                                        ...
# 0                         50    50      50       50          50  ...   50
# 1                        125   125     125      125         125  ...  125
#
#            Country/Region  Location   Pre-existing conditions and/or Symptoms  \
# Present.3
# 0                      50         41                                       33
# 1                     125        122                                      112
#
#            Instruments used  Socioeconomic Status  \
# Present.3
# 0                        31                    38
# 1                       111                   118
#
# ...

# %%
race = [165, 10]
ethnicity = [169, 6]
gender = [54, 121]
age = [50, 125]
x = [0, 1]

x_axis = np.arange(len(x))

plt.bar(x_axis - 0.2, race, 0.1, label = 'Race', color = 'darkorchid')
plt.bar(x_axis - 0.1, ethnicity, 0.1, label = 'Ethnicity', color = 'thistle')
plt.bar(x_axis, gender, 0.1, label = 'Sex', color = 'palevioletred')
plt.bar(x_axis + 0.1, age, 0.1, label = 'Age', color = 'orchid')

plt.xticks(x_axis, x_axis)
plt.xlabel("Variable Present/Absent")
plt.grid(axis='y')
plt.ylabel("Count")
plt.legend()
plt.show()

# %%
rOrE = pd.read_csv("Demographics Information - Ethnicity||Race.csv")
print(rOrE.shape)
rOrE.head()
# Out:
# (6, 21)
#                                    Study Name/Number  \
# 0  Visceral adipose tissue measurements during pr...
# 1  CAST RR Interval Sub-Study Database: Data from...
# 2  Cerebromicrovascular Disease in Elderly with D...
# 3  Q-Pain: A Question Answering Dataset to Measur...
# 4  Sleep-EDF Database: The sleep-edf database con...
#
#                                                 Race  Present     Ethnicity  \
# 0                                                  X        0  58 not white
# 1                           628 White; 141 non-white        1             X
# 2  White (94), African American (21), Asian (1), ...        1             X
# 3       Black, White, Asian, Hispanic (hypothetical)        1             X
# 4                                          Caucasian        1             X
#
#    Present.1                                  Study sample size Male Female  \
# 0          1                                                133    0    133
# ...

# %%
rOrE.groupby("Present").count() # counts for race reporting
# Out:
#          Study Name/Number  Race  Ethnicity  Present.1  Study sample size  \
# Present
# 0                        1     1          1          1                  1
# 1                        5     5          5          5                  5
#
#          Male  Female  Total N  Gender/Sex  Present.2  Age  Present.3  \
# Present
# 0           1       1        1           1          1    1          1
# 1           5       5        5           5          5    5          5
#
#          Country/Region  Location   Pre-existing conditions and/or Symptoms  \
# Present
# 0                     1          1                                        1
# 1                     5          5                                        2
#
#          Instruments used  Socioeconomic Status  \
# Present
# 0                       0                     1
# 1                       2                     3
#
#          Data Collected (differnent levels of)  \
# Present
# 0                                            0
# ...

# %%
rOrE.groupby("Present.1").count() # counts for ethnicity reporting
# Out:
#            Study Name/Number  Race  Present  Ethnicity  Study sample size  \
# Present.1
# 0                          5     5        5          5                  5
# 1                          1     1        1          1                  1
#
#            Male  Female  Total N  Gender/Sex  Present.2  Age  Present.3  \
# Present.1
# 0             5       5        5           5          5    5          5
# 1             1       1        1           1          1    1          1
#
#            Country/Region  Location   Pre-existing conditions and/or Symptoms  \
# Present.1
# 0                       5          5                                        2
# 1                       1          1                                        1
#
#            Instruments used  Socioeconomic Status  \
# Present.1
# 0                         2                     3
# 1                         0                     1
#
#            Data Collected (differnent levels of)  \
# Present.1
# ...

# %%
rOrE.groupby("Present.2").count() # counts for sex reporting
# Out:
#            Study Name/Number  Race  Present  Ethnicity  Present.1  \
# Present.2
# 0                          2     2        2          2          2
# 1                          4     4        4          4          4
#
#            Study sample size  Male  Female  Total N  Gender/Sex  Age  \
# Present.2
# 0                          2     2       2        2           2    2
# 1                          4     4       4        4           4    4
#
#            Present.3  Country/Region  Location   \
# Present.2
# 0                  2               2          2
# 1                  4               4          4
#
#            Pre-existing conditions and/or Symptoms  Instruments used  \
# Present.2
# 0                                                1                 1
# 1                                                2                 1
#
#            Socioeconomic Status  Data Collected (differnent levels of)  \
# Present.2
# ...

# %%
rOrE.groupby("Present.3").count() # counts for age reporting
# Out:
#            Study Name/Number  Race  Present  Ethnicity  Present.1  \
# Present.3
# 1                          6     6        6          6          6
#
#            Study sample size  Male  Female  Total N  Gender/Sex  Present.2  \
# Present.3
# 1                          6     6       6        6           6          6
#
#            Age  Country/Region  Location   \
# Present.3
# 1            6               6          6
#
#            Pre-existing conditions and/or Symptoms  Instruments used  \
# Present.3
# 1                                                3                 2
#
#            Socioeconomic Status  Data Collected (differnent levels of)  \
# Present.3
# 1                             4                                      4
#
#            Date of Study was Conducted/Published  \
# Present.3
# 1                                              0
#
#            Date of Study Posted on PhysioNet
# Present.3
# 1                                          0

# %% [markdown]
# Of the 6 studies that report race or ethnicity at all, 5 reported race, 1 reported ethnicity, 4 reported sex, and all 6 reported age.

# %%
raceAgeInd=pd.crosstab(participant_data["Present"],participant_data["Present.3"])
print('Race Age table :\n',raceAgeInd)
# Out:
# Race Age table :
#  Present.3   0    1
# Present
# 0          50  115
# 1           0   10

# %% [markdown]
# ### Chi Squared Test

# %% [markdown]
# Run chi2 test on race and age with null hypothesis that the two variables are independent and alternate hypothesis that the two are not.
# alpha = .05

# %%
import scipy.stats
from scipy.stats import chi2, chi2_contingency

chi2_stat, p, dof, expected = scipy.stats.chi2_contingency(raceAgeInd)
 
print(f"chi2 statistic:     {chi2_stat:.5g}")
print(f"p-value:            {p:.5g}")
print(f"degrees of freedom: {dof}")
print("expected frequencies:\n",expected)
# Out:
# chi2 statistic:     2.8875
# p-value:            0.089269
# degrees of freedom: 1
# expected frequencies:
#  [[ 47.14285714 117.85714286]
#  [  2.85714286   7.14285714]]

# %%
raceGenderInd=pd.crosstab(participant_data["Present"],participant_data["Present.2"])
print('Race Gender table :\n',raceGenderInd)
# Out:
# Race Gender table :
#  Present.2   0    1
# Present
# 0          52  113
# 1           2    8

# %% [markdown]
# Run chi2 test on race and gender with null hypothesis that the two variables are independent and alternate hypothesis that the two are not.
# alpha = .05

# %%
chi2_stat, p, dof, expected = scipy.stats.chi2_contingency(raceGenderInd)
 
print(f"chi2 statistic:     {chi2_stat:.5g}")
print(f"p-value:            {p:.5g}")
print(f"degrees of freedom: {dof}")
print("expected frequencies:\n",expected)
# Out:
# chi2 statistic:     0.17054
# p-value:            0.67963
# degrees of freedom: 1
# expected frequencies:
#  [[ 50.91428571 114.08571429]
#  [  3.08571429   6.91428571]]

# %%
ethnAgeInd=pd.crosstab(participant_data["Present.1"],participant_data["Present.3"])
print('Ethnicity Gender table :\n',ethnAgeInd)
# Out:
# Ethnicity Gender table :
#  Present.3   0    1
# Present.1
# 0          50  119
# 1           0    6

# %% [markdown]
# Run chi2 test on ethnicity and age with null hypothesis that the two variables are independent and alternate hypothesis that the two are not.
# alpha = .05

# %%
chi2_stat, p, dof, expected = scipy.stats.chi2_contingency(ethnAgeInd)
 
print(f"chi2 statistic:     {chi2_stat:.5g}")
print(f"p-value:            {p:.5g}")
print(f"degrees of freedom: {dof}")
print("expected frequencies:\n",expected)
# Out:
# chi2 statistic:     1.2469
# p-value:            0.26414
# degrees of freedom: 1
# expected frequencies:
#  [[ 48.28571429 120.71428571]
#  [  1.71428571   4.28571429]]

# %%
ethnGenderInd=pd.crosstab(participant_data["Present.1"],participant_data["Present.2"])
print('Ethnicity Gender table :\n',ethnGenderInd)
# Out:
# Ethnicity Gender table :
#  Present.2   0    1
# Present.1
# 0          54  115
# 1           0    6

# %% [markdown]
# Run chi2 test on ethnicity and gender with null hypothesis that the two variables are independent and alternate hypothesis that the two are not.
# alpha = .05

# %%
chi2_stat, p, dof, expected = scipy.stats.chi2_contingency(ethnGenderInd)
 
print(f"chi2 statistic:     {chi2_stat:.5g}")
print(f"p-value:            {p:.5g}")
print(f"degrees of freedom: {dof}")
print("expected frequencies:\n",expected)
# Out:
# chi2 statistic:     1.4773
# p-value:            0.22419
# degrees of freedom: 1
# expected frequencies:
#  [[ 52.14857143 116.85142857]
#  [  1.85142857   4.14857143]]

# %%
genderAgeInd=pd.crosstab(participant_data["Present.2"],participant_data["Present.3"])
print('Gender Age table :\n',genderAgeInd)
# Out:
# Gender Age table :
#  Present.3   0    1
# Present.2
# 0          42   12
# 1           8  113

# %% [markdown]
# Run chi2 test on age and gender with null hypothesis that the two variables are independent and alternate hypothesis that the two are not.
# alpha = .05

# %%
chi2_stat, p, dof, expected = scipy.stats.chi2_contingency(genderAgeInd)
 
print(f"chi2 statistic:     {chi2_stat:.5g}")
print(f"p-value:            {p:.5g}")
print(f"degrees of freedom: {dof}")
print("expected frequencies:\n",expected)
# Out:
# chi2 statistic:     89.204
# p-value:            3.5612e-21
# degrees of freedom: 1
# expected frequencies:
#  [[15.42857143 38.57142857]
#  [34.57142857 86.42857143]]

# %% [markdown]
# Our calculated p-value from the chi-squared test is significantly less than our alpha value of .05, thus we reject the null hypothesis that the variables of gender and age are reported independently.

# %%
raceEthnInd=pd.crosstab(participant_data["Present"],participant_data["Present.1"])
print('Race Ethn table :\n',raceEthnInd)
# Out:
# Race Ethn table :
#  Present.1    0  1
# Present
# 0          164  1
# 1            5  5

# %% [markdown]
# Run chi2 test on race and ethnicity with null hypothesis that the two variables are independent and alternate hypothesis that the two are not.

# %%
chi2_stat, p, dof, expected = scipy.stats.chi2_contingency(raceEthnInd)
 
print(f"chi2 statistic:     {chi2_stat:.5g}")
print(f"p-value:            {p:.5g}")
print(f"degrees of freedom: {dof}")
print("expected frequencies:\n",expected)
# Out:
# chi2 statistic:     55.358
# p-value:            1.0045e-13
# degrees of freedom: 1
# expected frequencies:
#  [[159.34285714   5.65714286]
#  [  9.65714286   0.34285714]]

# %% [markdown]
# Our calculated p-value from the chi-squared test is significantly less than our alpha value of .05, thus we reject the null hypothesis that the variables of gender and age are reported independently.

# %% [markdown]
# ### 95% Confidence Intervals

# %%
# Race 95% confidence interval
rdata = participant_data['Present'].to_numpy()
ci_race = stats.norm.interval(alpha = .95, loc = np.mean(rdata), scale = stats.sem(rdata))
print(ci_race)
# Out:
# (0.02265411221840316, 0.09163160206731112)

# %%
# Ethnicity 95% confidence interval
edata = participant_data['Present.1'].to_numpy()
ci_ethn = stats.norm.interval(alpha = .95, loc = np.mean(edata), scale = stats.sem(edata))
print(ci_ethn)
# Out:
# (0.007248969862788026, 0.061322458708640545)

# %%
# Gender 95% confidence interval
gdata = participant_data['Present.2'].to_numpy()
ci_gender = stats.norm.interval(alpha = .95, loc = np.mean(gdata), scale = stats.sem(gdata))
print(ci_gender)
# Out:
# (0.6227968355857586, 0.7600603072713842)

# %%
# Age 95% confidence interval
adata = participant_data['Present.3'].to_numpy()
ci_age = stats.norm.interval(alpha = .95, loc = np.mean(adata), scale = stats.sem(adata))
print(ci_age)
# Out:
# (0.6471620855128555, 0.7814093430585731)

# %% [markdown]
# Because the 95% Confidence Intervals for Race/Ethnicity do not overlap with those for Age/Gender, there is significant statistical evidence that age and gender variables are reported at a higher frequency than race and ethnicity are.

# %% [markdown]
# ### Hypotheses Testing

# %%
print("Race/Ethnicity:")
print(stats.ttest_ind(rdata, edata))
# Out:
# Ttest_indResult(statistic=1.0222744470273355, pvalue=0.30736113417814254)

# %% [markdown]
# We consider the null hypothesis that the reporting for race equal to the reporting of ethnicity. The alternative hypothesis is that the reporting of race and ethnicity are not equal. We can conduct a two-sided t-test with an &alpha; = .05.
#
# The 2-sided p-value is about .307, which is not statistically significant at the .05 level, thus we cannot reject the null hypothesis. Race and ethnicity are reported at equal freqnecies.

# %%
print("Race/Gender:")
print(stats.ttest_ind(rdata, gdata))
# Out:
# Race/Gender:
# Ttest_indResult(statistic=-16.185077845597007, pvalue=2.543875412514354e-44)

# %% [markdown]
# We consider the null hypothesis that the reporting for race equal to the reporting of gender. The alternative hypothesis is that the reporting of race and gender are not equal. We can conduct a two-sided t-test with an &alpha; = .05.
#
# The 2-sided p-value is about .2.54e-44, which is statistically significant at the .05 level, thus we reject the null hypothesis; race and gender are not reported at equal frequencies.

# %%
print("Race/Age:")
print(stats.ttest_ind(rdata, adata))
# Out:
# Race/Age:
# Ttest_indResult(statistic=-17.067068000291737, pvalue=6.982678164764769e-48)

# %% [markdown]
# We consider the null hypothesis that the reporting for race equal to the reporting of age. The alternative hypothesis is that the reporting of race and age are not equal. We can conduct a two-sided t-test with an &alpha; = .05.
#
# The 2-sided p-value is about 6.98e-48, which is statistically significant at the .05 level, thus we reject the null hypothesis; race and age are not reported at equal frequencies.

# %%
print("Ethnicity/Gender:")
print(stats.ttest_ind(edata, gdata))
# Out:
# Ethnicity/Gender:
# Ttest_indResult(statistic=-17.460493676516222, pvalue=1.7777248763079305e-49)

# %% [markdown]
# We consider the null hypothesis that the reporting for ethnicity equal to the reporting of gender. The alternative hypothesis is that the reporting of ethnicity and gender are not equal. We can conduct a two-sided t-test with an &alpha; = .05.
#
# The 2-sided p-value is about .1.78e-49, which is statistically significant at the .05 level, thus we reject the null hypothesis; ethnicity and gender are not reported at equal frequencies.

# %%
print("Ethnicity/Age:")
print(stats.ttest_ind(edata, adata))
# Out:
# Ethnicity/Age:
# Ttest_indResult(statistic=-18.41762676815135, pvalue=2.313228450494931e-53)

# %% [markdown]
# We consider the null hypothesis that the reporting for ethnicity equal to the reporting of age. The alternative hypothesis is that the reporting of ethnicity and age are not equal. We can conduct a two-sided t-test with an &alpha; = .05.
#
# The 2-sided p-value is about 2.31e-53, which is statistically significant at the .05 level, thus we reject the null hypothesis; ethnicity and age are not reported at equal frequencies.

# %%
print("Age/Gender:")
print(stats.ttest_ind(adata, gdata))
# Out:
# Age/Gender:
# Ttest_indResult(statistic=0.4666607067978697, pvalue=0.6410346523291042)

# %% [markdown]
# We consider the null hypothesis that the reporting for age equal to the reporting of gender. The alternative hypothesis is that the reporting of age and gender are not equal. We can conduct a two-sided t-test with an &alpha; = .05.
#
# The 2-sided p-value is about .641, which is not statistically significant at the .05 level, thus we cannot reject the null hypothesis. Age and gender are reported at equal frequencies.
#
#
# If we want to adjust the null hypotheses and alternate hypotheses to be one-tailed (i.e. reported >, reported <=), we can keep these results and divide the calculated p-value from each test by 2 to obtain the 1-tailed p-value. In each case above, the final result is not changed, we find that the tests in which we rejected the two-tailed null hypothesis we will also reject the one-tailed hypothesis, and vice versa. (https://www.graphpad.com/guides/prism/latest/statistics/one-tail_vs__two-tail_p_values.htm)
