# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

participant_data = pd.read_csv("Demographics Information - Human Participants.csv")
print(participant_data.shape)
participant_data.head()
# Out:
# (175, 27)
#                                    Study Name/Number  \
# 0  Abdominal and Direct Fetal ECG Database: Multi...
# 1  AF Termination Challenge Database: ECG recordi...
# 2  AHA Database Sample Excluded Record: Two ECG s...
# 3  A large scale 12-lead electrocardiogram databa...
# 4  A multi-camera and multimodal dataset for post...
#
#    Publication (0) vs Physionet (1) Race  Present Ethnicity  Present.1  \
# 0                               NaN    X        0         X          0
# 1                               NaN    X        0         X          0
# 2                               NaN    X        0         X          0
# 3                               NaN    X        0         X          0
# 4                               NaN    X        0         X          0
#
#                                    Study sample size  \
# 0                     5 women in labor were analyzed
# 1  Three groups in Learning Set: 1.  Group N (non...
# 2  80 recordings (10 for each existing condition)...
# 3                                   45, 152 patients
# 4                                                 14
#
#                                           Gender/Sex  Present.2 Male  ...  \
# 0  Unknown (collected from fetal heartbeats of pr...          0    X  ...
# 1                                                  X          0    X  ...
# 2                                                  X          0    X  ...
# 3                                    Male and Female          1    X  ...
# 4                                10 males; 4 females          1   10  ...
#
#   Max Age (years) Country/Region  \
# 0            0.79         Poland
# 1               X            USA
# 2               X            USA
# 3               X          China
# 4              30       Portugal
#
#                                            Location   \
# 0  Department of Obstetrics at the Medical Univer...
# 1                                                  X
# 2                  Washington University (St. Louis)
# 3  Chapman University, Shaoxing People's Hospital...
# 4                     Portugal (University of Minho)
#
#              Pre-existing conditions and/or Symptoms  \
# 0                                     Women in labor
# 1                                                  X
# 2  No ventricular ectopy, isolated unifocal PVCs,...
# 3  Includes information about pre-existing condit...
# 4           No clinical history of any abnormalities
#
#                                     Instruments used Socioeconomic Status  \
# 0  KOMPOREL System (ITAM Institute, Zabrze, Polan...                    X
# 1                   Not listed; two ECG signals used                    X
# 2                   Not listed; two ECG signals used                    X
# 3                                 GE MUSE ECG System                    X
# 4                                        MVN BIOMECH                    X
#
#                Data Collected (differnent levels of)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  walking straight in a corridor, turning right ...
#
#   Date Study was Conducted/Published Date Study Posted on PhysioNet  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
#
#                        Field
# 0  cardiac_electrophysiology
# 1  cardiac_electrophysiology
# 2  cardoac_electrophysiology
# 3  cardiac_electrophysiology
# 4        gait/balance/motion
#
# [5 rows x 27 columns]

# %%
plt.show(sns.displot(x='Present', data=participant_data))

plt.show(sns.displot(x='Present.1', data=participant_data))

# plt.show(sns.displot(x="Present", y="Present.2", data=participant_data, cbar=True))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
participant_data.groupby("Present").count() # counts for race reporting
# Out:
#          Study Name/Number  Publication (0) vs Physionet (1)  Race  Ethnicity  \
# Present
# 0                      165                                 8   165        165
# 1                       10                                 2    10         10
#
#          Present.1  Study sample size  Gender/Sex  Present.2  Male  Female  \
# Present
# 0              165                165         163        165   165     165
# 1               10                 10          10         10    10      10
#
#          ...  Max Age (years)  Country/Region  Location   \
# Present  ...
# 0        ...               46             165        153
# 1        ...                0              10         10
#
#          Pre-existing conditions and/or Symptoms  Instruments used  \
# Present
# 0                                            139               135
# 1                                              6                 7
#
#          Socioeconomic Status  Data Collected (differnent levels of)  \
# Present
# 0                         148                                    127
# 1                           8                                      9
#
#          Date Study was Conducted/Published  Date Study Posted on PhysioNet  \
# Present
# 0                                         0                              23
# 1                                         0                               0
#
#          Field
# Present
# 0          165
# 1           10
#
# [2 rows x 26 columns]

# %%
participant_data.groupby("Present.1").count() # ethnicity reporting
# Out:
#            Study Name/Number  Publication (0) vs Physionet (1)  Race  Present  \
# Present.1
# 0                        169                                10   169      169
# 1                          6                                 0     6        6
#
#            Ethnicity  Study sample size  Gender/Sex  Present.2  Male  Female  \
# Present.1
# 0                169                169         167        169   169     169
# 1                  6                  6           6          6     6       6
#
#            ...  Max Age (years)  Country/Region  Location   \
# Present.1  ...
# 0          ...               46             169        157
# 1          ...                0               6          6
#
#            Pre-existing conditions and/or Symptoms  Instruments used  \
# Present.1
# 0                                              140               137
# 1                                                5                 5
#
#            Socioeconomic Status  Data Collected (differnent levels of)  \
# Present.1
# 0                           150                                    131
# 1                             6                                      5
#
#            Date Study was Conducted/Published  Date Study Posted on PhysioNet  \
# Present.1
# 0                                           0                              23
# 1                                           0                               0
#
#            Field
# Present.1
# 0            169
# 1              6
#
# [2 rows x 26 columns]

# %%
participant_data.groupby("Present.2").count() # gender reporting
# Out:
#            Study Name/Number  Publication (0) vs Physionet (1)  Race  Present  \
# Present.2
# 0                         44                                 1    44       44
# 1                        131                                 9   131      131
#
#            Ethnicity  Present.1  Study sample size  Gender/Sex  Male  Female  \
# Present.2
# 0                 44         44                 44          44    44      44
# 1                131        131                131         129   131     131
#
#            ...  Max Age (years)  Country/Region  Location   \
# Present.2  ...
# 0          ...               11              44         38
# 1          ...               35             131        125
#
#            Pre-existing conditions and/or Symptoms  Instruments used  \
# Present.2
# 0                                               32                30
# 1                                              113               112
#
#            Socioeconomic Status  Data Collected (differnent levels of)  \
# Present.2
# 0                            35                                     29
# 1                           121                                    107
#
#            Date Study was Conducted/Published  Date Study Posted on PhysioNet  \
# Present.2
# 0                                           0                               3
# 1                                           0                              20
#
#            Field
# Present.2
# 0             44
# 1            131
#
# [2 rows x 26 columns]

# %%
participant_data.groupby("Present.3").count() # age reporting
# Out:
#            Study Name/Number  Publication (0) vs Physionet (1)  Race  Present  \
# Present.3
# 0                         49                                 1    49       49
# 1                        126                                 9   126      126
#
#            Ethnicity  Present.1  Study sample size  Gender/Sex  Present.2  \
# Present.3
# 0                 49         49                 49          49         49
# 1                126        126                126         124        126
#
#            Male  ...  Max Age (years)  Country/Region  Location   \
# Present.3        ...
# 0            49  ...               10              49         40
# 1           126  ...               36             126        123
#
#            Pre-existing conditions and/or Symptoms  Instruments used  \
# Present.3
# 0                                               32                30
# 1                                              113               112
#
#            Socioeconomic Status  Data Collected (differnent levels of)  \
# Present.3
# 0                            37                                     28
# 1                           119                                    108
#
#            Date Study was Conducted/Published  Date Study Posted on PhysioNet  \
# Present.3
# 0                                           0                               3
# 1                                           0                              20
#
#            Field
# Present.3
# 0             49
# 1            126
#
# [2 rows x 26 columns]

# %%
race = [165, 10]
ethnicity = [169, 6]
gender = [54, 121]
age = [50, 125]
x = [0, 1]

x_axis = np.arange(len(x))

plt.bar(x_axis - 0.2, race, 0.1, label = 'Race', color = 'darkorchid')
plt.bar(x_axis - 0.1, ethnicity, 0.1, label = 'Ethnicity', color = 'thistle')
plt.bar(x_axis, gender, 0.1, label = 'Sex', color = 'palevioletred')
plt.bar(x_axis + 0.1, age, 0.1, label = 'Age', color = 'orchid')

plt.xticks(x_axis, x_axis)
plt.xlabel("Variable Present/Absent")
plt.grid(axis='y')
plt.ylabel("Count")
plt.legend()
plt.show()

# %%
chi_sq_data = pd.read_csv("Demographics Information - Chi-Squared.csv")
chi_sq_data.head()
# Out:
#                                    Study Name/Number Race  Present Ethnicity  \
# 0  Abdominal and Direct Fetal ECG Database: Multi...    X        0         X
# 1  AF Termination Challenge Database: ECG recordi...    X        0         X
# 2  AHA Database Sample Excluded Record: Two ECG s...    X        0         X
# 3  A large scale 12-lead electrocardiogram databa...    X        0         X
# 4  A multi-camera and multimodal dataset for post...    X        0         X
#
#    Present.1                                  Study sample size  \
# 0          0                     5 women in labor were analyzed
# 1          0  Three groups in Learning Set: 1.  Group N (non...
# 2          0  80 recordings (10 for each existing condition)...
# 3          0                                   45, 152 patients
# 4          0                                                 14
#
#                                           Gender/Sex  Present.2 Male Female  \
# 0  Unknown (collected from fetal heartbeats of pr...          0    X      X
# 1                                                  X          0    X      X
# 2                                                  X          0    X      X
# 3                                    Male and Female          1    X      X
# 4                                10 males; 4 females          1   10      4
#
#    ... Max Age (years) Country/Region  \
# 0  ...            0.79         Poland
# 1  ...               X            USA
# 2  ...               X            USA
# 3  ...               X          China
# 4  ...              30       Portugal
#
#                                            Location   \
# 0  Department of Obstetrics at the Medical Univer...
# 1                                                  X
# 2                  Washington University (St. Louis)
# 3  Chapman University, Shaoxing People's Hospital...
# 4                     Portugal (University of Minho)
#
#              Pre-existing conditions and/or Symptoms  \
# 0                                     Women in labor
# 1                                                  X
# 2  No ventricular ectopy, isolated unifocal PVCs,...
# 3  Includes information about pre-existing condit...
# 4           No clinical history of any abnormalities
#
#                                     Instruments used Socioeconomic Status  \
# 0  KOMPOREL System (ITAM Institute, Zabrze, Polan...                    X
# 1                   Not listed; two ECG signals used                    X
# 2                   Not listed; two ECG signals used                    X
# 3                                 GE MUSE ECG System                    X
# 4                                        MVN BIOMECH                    X
#
#                Data Collected (differnent levels of)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  walking straight in a corridor, turning right ...
#
#   Date Study was Conducted/Published Date Study Posted on PhysioNet  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
#
#                        Field
# 0  cardiac_electrophysiology
# 1  cardiac_electrophysiology
# 2  cardoac_electrophysiology
# 3  cardiac_electrophysiology
# 4        gait/balance/motion
#
# [5 rows x 26 columns]

# %% [markdown]
# Of the 6 studies that report race or ethnicity at all, 5 reported race, 1 reported ethnicity, 4 reported sex, and all 6 reported age.

# %% [markdown]
# ### Chi Squared Test

# %%
raceAgeInd=pd.crosstab(chi_sq_data["Present"],chi_sq_data["Present.3"])
print('Race Age table :\n',raceAgeInd)
# Out:
# Race Age table :
#  Present.3   0    1
# Present
# 0          40  112
# 1           0   10

# %% [markdown]
# Run chi2 test on race and age with null hypothesis that the two variables are independent and alternate hypothesis that the two are not.
# alpha = .05

# %%
import scipy.stats
from scipy.stats import chi2, chi2_contingency

chi2_stat, p, dof, expected = scipy.stats.chi2_contingency(raceAgeInd)
 
print(f"chi2 statistic:     {chi2_stat:.5g}")
print(f"p-value:            {p:.5g}")
print(f"degrees of freedom: {dof}")
print("expected frequencies:\n",expected)
# Out:
# chi2 statistic:     2.2225
# p-value:            0.13602
# degrees of freedom: 1
# expected frequencies:
#  [[ 37.5308642 114.4691358]
#  [  2.4691358   7.5308642]]

# %%
raceGenderInd=pd.crosstab(chi_sq_data["Present"],chi_sq_data["Present.2"])
print('Race Gender table :\n',raceGenderInd)
# Out:
# Race Gender table :
#  Present.2   0    1
# Present
# 0          36  116
# 1           0   10

# %% [markdown]
# Run chi2 test on race and gender with null hypothesis that the two variables are independent and alternate hypothesis that the two are not.
# alpha = .05

# %%
chi2_stat, p, dof, expected = scipy.stats.chi2_contingency(raceGenderInd)
 
print(f"chi2 statistic:     {chi2_stat:.5g}")
print(f"p-value:            {p:.5g}")
print(f"degrees of freedom: {dof}")
print("expected frequencies:\n",expected)
# Out:
# chi2 statistic:     1.829
# p-value:            0.17625
# degrees of freedom: 1
# expected frequencies:
#  [[ 33.77777778 118.22222222]
#  [  2.22222222   7.77777778]]

# %%
ethnAgeInd=pd.crosstab(chi_sq_data["Present.1"],chi_sq_data["Present.3"])
print('Ethnicity Gender table :\n',ethnAgeInd)
# Out:
# Ethnicity Gender table :
#  Present.3   0    1
# Present.1
# 0          40  116
# 1           0    6

# %% [markdown]
# Run chi2 test on ethnicity and age with null hypothesis that the two variables are independent and alternate hypothesis that the two are not.
# alpha = .05

# %%
chi2_stat, p, dof, expected = scipy.stats.chi2_contingency(ethnAgeInd)
 
print(f"chi2 statistic:     {chi2_stat:.5g}")
print(f"p-value:            {p:.5g}")
print(f"degrees of freedom: {dof}")
print("expected frequencies:\n",expected)
# Out:
# chi2 statistic:     0.89663
# p-value:            0.34369
# degrees of freedom: 1
# expected frequencies:
#  [[ 38.51851852 117.48148148]
#  [  1.48148148   4.51851852]]

# %%
ethnGenderInd=pd.crosstab(chi_sq_data["Present.1"],chi_sq_data["Present.2"])
print('Ethnicity Gender table :\n',ethnGenderInd)
# Out:
# Ethnicity Gender table :
#  Present.2   0    1
# Present.1
# 0          36  120
# 1           0    6

# %% [markdown]
# Run chi2 test on ethnicity and gender with null hypothesis that the two variables are independent and alternate hypothesis that the two are not.
# alpha = .05

# %%
chi2_stat, p, dof, expected = scipy.stats.chi2_contingency(ethnGenderInd)
 
print(f"chi2 statistic:     {chi2_stat:.5g}")
print(f"p-value:            {p:.5g}")
print(f"degrees of freedom: {dof}")
print("expected frequencies:\n",expected)
# Out:
# chi2 statistic:     0.6954
# p-value:            0.40433
# degrees of freedom: 1
# expected frequencies:
#  [[ 34.66666667 121.33333333]
#  [  1.33333333   4.66666667]]

# %%
genderAgeInd=pd.crosstab(chi_sq_data["Present.2"],chi_sq_data["Present.3"])
print('Gender Age table :\n',genderAgeInd)
# Out:
# Gender Age table :
#  Present.3   0    1
# Present.2
# 0          28    8
# 1          12  114

# %% [markdown]
# Run chi2 test on age and gender with null hypothesis that the two variables are independent and alternate hypothesis that the two are not.
# alpha = .05

# %%
chi2_stat, p, dof, expected = scipy.stats.chi2_contingency(genderAgeInd)
 
print(f"chi2 statistic:     {chi2_stat:.5g}")
print(f"p-value:            {p:.5g}")
print(f"degrees of freedom: {dof}")
print("expected frequencies:\n",expected)
# Out:
# chi2 statistic:     66.527
# p-value:            3.4516e-16
# degrees of freedom: 1
# expected frequencies:
#  [[ 8.88888889 27.11111111]
#  [31.11111111 94.88888889]]

# %% [markdown]
# Our calculated p-value from the chi-squared test is significantly less than our alpha value of .05, thus we reject the null hypothesis that the variables of gender and age are reported independently.

# %%
raceEthnInd=pd.crosstab(chi_sq_data["Present"],chi_sq_data["Present.1"])
print('Race Ethn table :\n',raceEthnInd)
# Out:
# Race Ethn table :
#  Present.1    0  1
# Present
# 0          151  1
# 1            5  5

# %% [markdown]
# Run chi2 test on race and ethnicity with null hypothesis that the two variables are independent and alternate hypothesis that the two are not.

# %%
chi2_stat, p, dof, expected = scipy.stats.chi2_contingency(raceEthnInd)
 
print(f"chi2 statistic:     {chi2_stat:.5g}")
print(f"p-value:            {p:.5g}")
print(f"degrees of freedom: {dof}")
print("expected frequencies:\n",expected)
# Out:
# chi2 statistic:     50.962
# p-value:            9.4164e-13
# degrees of freedom: 1
# expected frequencies:
#  [[146.37037037   5.62962963]
#  [  9.62962963   0.37037037]]

# %% [markdown]
# Our calculated p-value from the chi-squared test is significantly less than our alpha value of .05, thus we reject the null hypothesis that the variables of gender and age are reported independently.
